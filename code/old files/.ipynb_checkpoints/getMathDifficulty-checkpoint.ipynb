# %%
import pandas as pd; pd.set_option('display.max_columns', 30)
import numpy as np
from cmlreaders import CMLReader, get_data_index
from ptsa.data.filters import ButterworthFilter
import sys
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from pylab import *
from copy import copy
from scipy import stats
import pickle
plt.rcParams['pdf.fonttype'] = 42; plt.rcParams['ps.fonttype'] = 42 # fix fonts for Illustrator
sys.path.append('/home1/john/Downloads/ptsa_plot-master/')
sys.path.append('/home1/john/johnModules')
from brain_labels import MTL_labels, LTC_labels, PFC_labels, OTHER_labels, ALL_labels # all location labels
# %load_ext autoreload
# %autoreload
from general import *
from SWRmodule import *

df = get_data_index("ltp") # all RAM subjects
exp = 'ltpFR2'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
np.unique(df.experiment)
exp_df = df[df.experiment==exp]
np.shape(exp_df)
exp_df
print(str(len(np.unique(exp_df.subject)))+' '+exp+' subjects')
# Out:
# array(['NiclsCourierClosedLoop', 'NiclsCourierReadOnly', 'VFFR',
#        'ltpDBOY1', 'ltpFR2', 'ltpRepFR', 'prelim'], dtype=object)
# (2470, 9)
#                                              all_events experiment  \
# 0     protocols/ltp/subjects/LTP093/experiments/ltpF...     ltpFR2
# 1     protocols/ltp/subjects/LTP093/experiments/ltpF...     ltpFR2
# 2     protocols/ltp/subjects/LTP093/experiments/ltpF...     ltpFR2
# 3     protocols/ltp/subjects/LTP093/experiments/ltpF...     ltpFR2
# 4     protocols/ltp/subjects/LTP093/experiments/ltpF...     ltpFR2
# ...                                                 ...        ...
# 2594  protocols/ltp/subjects/LTP393/experiments/ltpF...     ltpFR2
# 2595  protocols/ltp/subjects/LTP393/experiments/ltpF...     ltpFR2
# 2596  protocols/ltp/subjects/LTP393/experiments/ltpF...     ltpFR2
# 2597  protocols/ltp/subjects/LTP393/experiments/ltpF...     ltpFR2
# 2598  protocols/ltp/subjects/LTP393/experiments/ltpF...     ltpFR2
#
#      import_type                                        math_events  \
# 0          build  protocols/ltp/subjects/LTP093/experiments/ltpF...
# 1          build  protocols/ltp/subjects/LTP093/experiments/ltpF...
# 2          build  protocols/ltp/subjects/LTP093/experiments/ltpF...
# 3          build  protocols/ltp/subjects/LTP093/experiments/ltpF...
# 4          build  protocols/ltp/subjects/LTP093/experiments/ltpF...
# ...          ...                                                ...
# 2594       build  protocols/ltp/subjects/LTP393/experiments/ltpF...
# 2595       build  protocols/ltp/subjects/LTP393/experiments/ltpF...
# 2596       build  protocols/ltp/subjects/LTP393/experiments/ltpF...
# 2597       build  protocols/ltp/subjects/LTP393/experiments/ltpF...
# 2598       build  protocols/ltp/subjects/LTP393/experiments/ltpF...
#
#      original_session  session subject subject_alias  \
# 0                   0        0  LTP093        LTP093
# 1                   1        1  LTP093        LTP093
# 2                  10       10  LTP093        LTP093
# 3                  11       11  LTP093        LTP093
# 4                  12       12  LTP093        LTP093
# ...               ...      ...     ...           ...
# 2594                5        5  LTP393        LTP393
# 2595                6        6  LTP393        LTP393
# 2596                7        7  LTP393        LTP393
# 2597                8        8  LTP393        LTP393
# 2598                9        9  LTP393        LTP393
#
#                                             task_events
# 0     protocols/ltp/subjects/LTP093/experiments/ltpF...
# 1     protocols/ltp/subjects/LTP093/experiments/ltpF...
# 2     protocols/ltp/subjects/LTP093/experiments/ltpF...
# 3     protocols/ltp/subjects/LTP093/experiments/ltpF...
# 4     protocols/ltp/subjects/LTP093/experiments/ltpF...
# ...                                                 ...
# 2594  protocols/ltp/subjects/LTP393/experiments/ltpF...
# 2595  protocols/ltp/subjects/LTP393/experiments/ltpF...
# 2596  protocols/ltp/subjects/LTP393/experiments/ltpF...
# 2597  protocols/ltp/subjects/LTP393/experiments/ltpF...
# 2598  protocols/ltp/subjects/LTP393/experiments/ltpF...
#
# [2470 rows x 9 columns]
# 127 ltpFR2 subjects

# %%
def EEGReadDFRow(row):
    from cmlreaders import CMLReader, get_data_index
    rd = row._asdict() # this takes df and takes values from 1 row as a dict
    return CMLReader(rd['subject'], rd['experiment'], rd['session'], \
                     montage=0, localization=0) # these two always 0s for EEG

for row in exp_df.itertuples(): #sub_df.itertuples():   
    sub = row.subject; session = row.session; exp = row.experiment

    reader = EEGReadDFRow(row)
    evs = reader.load('task_events')
    evs_math = reader.load('all_events')
    evs_math = evs_math[(evs_math.type=='PROB')]   # get math problems only 
    import ipdb; ipdb.set_trace()
# Out:
# --Call--
# > /home1/john/anaconda3/envs/env1/lib/python3.7/site-packages/IPython/core/displayhook.py(252)__call__()
#     251
# --> 252     def __call__(self, result=None):
#     253         """Printing with history cache management.
# ipdb>  u
# > <ipython-input-23-3a1eeec9f3f2>(14)<module>()
#      12     evs_math = reader.load('all_events')
#      13     evs_math = evs_math[(evs_math.type=='PROB')]
# ---> 14     import ipdb; ipdb.set_trace()
# ipdb>  l
#       9
#      10     reader = EEGReadDFRow(row)
#      11     evs = reader.load('task_events')
#      12     evs_math = reader.load('all_events')
#      13     evs_math = evs_math[(evs_math.type=='PROB')]
# ---> 14     import ipdb; ipdb.set_trace()
# ipdb>  evs
#      eegoffset  begin_distractor  begin_math_correct  \
# 0       208336              -999                -999
# 1       285929                 0                -999
# 2       287177                 0                -999
# 3       288442                 0                -999
# 4       289815                 0                -999
# ..         ...               ...                 ...
# 869    2788365             24000                -999
# 870    2790926             24000                -999
# 871    2791475             24000                -999
# 872    2798827             24000                -999
# 873    2824461              -999                -999
#
#                                                eegfile  eogArtifact  \
# 0    /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 1    /protocols/ltp/subjects/LTP093/experiments/ltp...            1
# 2    /protocols/ltp/subjects/LTP093/experiments/ltp...            0
# 3    /protocols/ltp/subjects/LTP093/experiments/ltp...            0
# 4    /protocols/ltp/subjects/LTP093/experiments/ltp...            3
# ..                                                 ...          ...
# 869  /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 870  /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 871  /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 872  /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 873  /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
#
#     experiment  final_distractor  final_math_correct  intruded  intrusion  \
# 0       ltpFR2              -999                -999         0       -999
# 1       ltpFR2             24000                  10         0       -999
# 2       ltpFR2             24000                  10         0       -999
# 3       ltpFR2             24000                  10         0       -999
# 4       ltpFR2             24000                  10         0       -999
# ..         ...               ...                 ...       ...        ...
# 869     ltpFR2             24000                -999         0          0
# 870     ltpFR2             24000                -999         0          0
# 871     ltpFR2             24000                -999         0          0
# 872     ltpFR2             24000                -999         0          0
# 873     ltpFR2              -999                -999         0       -999
#
#     item_name  item_num  montage  msoffset         mstime phase protocol  \
# 0                  -999        0         0  1409670982007            ltp
# 1     BALLOON        75        0         1  1409671137192            ltp
# 2     MAILBOX       857        0         1  1409671139687            ltp
# 3      FLOWER       584        0         1  1409671142218            ltp
# 4    DAUGHTER       442        0         1  1409671144963            ltp
# ..        ...       ...      ...       ...            ...   ...      ...
# 869    STAPLE      1371        0        20  1409676141988            ltp
# 870    PATROL      1027        0        20  1409676147110            ltp
# 871   SERVANT      1271        0        20  1409676148208            ltp
# 872    CASHEW       253        0        20  1409676162911            ltp
# 873                -999        0         0  1409676214179            ltp
#
#      recalled  rectime  serialpos  session subject  trial        type
# 0       False     -999       -999        0  LTP093   -999  SESS_START
# 1        True     -999          1        0  LTP093      1        WORD
# 2        True     -999          2        0  LTP093      1        WORD
# 3        True     -999          3        0  LTP093      1        WORD
# 4        True     -999          4        0  LTP093      1        WORD
# ..        ...      ...        ...      ...     ...    ...         ...
# 869     False    10186         15        0  LTP093     24    REC_WORD
# 870     False    15308         18        0  LTP093     24    REC_WORD
# 871     False    16406         19        0  LTP093     24    REC_WORD
# 872     False    31109          1        0  LTP093     24    REC_WORD
# 873     False     -999       -999        0  LTP093     24    SESS_END
#
# [874 rows x 24 columns]
# ipdb>  evs.columns
# Index(['eegoffset', 'begin_distractor', 'begin_math_correct', 'eegfile',
#        'eogArtifact', 'experiment', 'final_distractor', 'final_math_correct',
#        'intruded', 'intrusion', 'item_name', 'item_num', 'montage', 'msoffset',
#        'mstime', 'phase', 'protocol', 'recalled', 'rectime', 'serialpos',
#        'session', 'subject', 'trial', 'type'],
#       dtype='object')
# ipdb>  evs_math.columns
# Index(['eegoffset', 'answer', 'begin_distractor', 'begin_math_correct',
#        'eegfile', 'eogArtifact', 'experiment', 'final_distractor',
#        'final_math_correct', 'intruded', 'intrusion', 'iscorrect', 'item_name',
#        'item_num', 'list', 'montage', 'msoffset', 'mstime', 'phase',
#        'protocol', 'recalled', 'rectime', 'serialpos', 'session', 'subject',
#        'test', 'trial', 'type'],
#       dtype='object')
# ipdb>  evs_math
#       eegoffset  answer  begin_distractor  begin_math_correct  \
# 2        249475      24              -999                -999
# 3        252312      20              -999                -999
# 4        253768      11              -999                -999
# 32       317424      21              -999                -999
# 33       319388       8              -999                -999
# ...         ...     ...               ...                 ...
# 1323    2775492      18              -999                -999
# 1324    2777355      23              -999                -999
# 1325    2778711      13              -999                -999
# 1326    2779635       6              -999                -999
# 1327    2780409      18              -999                -999
#
#                                                 eegfile  eogArtifact  \
# 2     /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 3     /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 4     /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 32    /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 33    /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# ...                                                 ...          ...
# 1323  /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 1324  /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 1325  /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 1326  /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
# 1327  /protocols/ltp/subjects/LTP093/experiments/ltp...           -1
#
#      experiment  final_distractor  final_math_correct  intruded  intrusion  \
# 2        ltpFR2              -999                -999      -999       -999
# 3        ltpFR2              -999                -999      -999       -999
# 4        ltpFR2              -999                -999      -999       -999
# 32       ltpFR2              -999                -999      -999       -999
# 33       ltpFR2              -999                -999      -999       -999
# ...         ...               ...                 ...       ...        ...
# 1323     ltpFR2              -999                -999      -999       -999
# 1324     ltpFR2              -999                -999      -999       -999
# 1325     ltpFR2              -999                -999      -999       -999
# 1326     ltpFR2              -999                -999      -999       -999
# 1327     ltpFR2              -999                -999      -999       -999
#
#       iscorrect item_name  item_num  list  montage  msoffset         mstime  \
# 2             1                -999    -1        0         1  1409671064284
# 3             1                -999    -1        0         1  1409671069958
# 4             1                -999    -1        0         1  1409671072871
# 32            1                -999     1        0         1  1409671200181
# 33            1                -999     1        0         1  1409671204109
# ...         ...       ...       ...   ...      ...       ...            ...
# 1323          1                -999    36        0         1  1409676116242
# 1324          1                -999    36        0         1  1409676119969
# 1325          1                -999    36        0         1  1409676122681
# 1326          1                -999    36        0         1  1409676124529
# 1327          1                -999    36        0         1  1409676126077
#
#      phase protocol  recalled  rectime  serialpos  session subject       test  \
# 2               ltp      -999     5611       -999        0  LTP093  [7, 8, 9]
# 3               ltp      -999     2849       -999        0  LTP093  [3, 8, 9]
# 4               ltp      -999     2169       -999        0  LTP093  [2, 6, 3]
# 32              ltp      -999     3859       -999        0  LTP093  [6, 6, 9]
# 33              ltp      -999     2690       -999        0  LTP093  [3, 4, 1]
# ...    ...      ...       ...      ...        ...      ...     ...        ...
# 1323            ltp      -999     3662       -999        0  LTP093  [6, 5, 7]
# 1324            ltp      -999     2639       -999        0  LTP093  [6, 9, 8]
# 1325            ltp      -999     1783       -999        0  LTP093  [4, 8, 1]
# 1326            ltp      -999     1480       -999        0  LTP093  [4, 1, 1]
# 1327            ltp      -999     3060       -999        0  LTP093  [7, 7, 4]
#
#       trial  type
# 2      -999  PROB
# 3      -999  PROB
# 4      -999  PROB
# 32     -999  PROB
# 33     -999  PROB
# ...     ...   ...
# 1323   -999  PROB
# 1324   -999  PROB
# 1325   -999  PROB
# 1326   -999  PROB
# 1327   -999  PROB
#
# [393 rows x 28 columns]
# ipdb>  evs.test
# *** AttributeError: 'DataFrame' object has no attribute 'test'
# ipdb>  evs_math.test
# 2       [7, 8, 9]
# 3       [3, 8, 9]
# 4       [2, 6, 3]
# 32      [6, 6, 9]
# 33      [3, 4, 1]
#           ...
# 1323    [6, 5, 7]
# 1324    [6, 9, 8]
# 1325    [4, 8, 1]
# 1326    [4, 1, 1]
# 1327    [7, 7, 4]
# Name: test, Length: 393, dtype: object
# ipdb>  evs_math.test.unique()
# *** TypeError: unhashable type: 'list'
# ipdb>  np.unique(evs_math.test)
# array([list([1, 1, 4]), list([1, 1, 5]), list([1, 1, 7]), list([1, 1, 9]),
#        list([1, 2, 1]), list([1, 2, 5]), list([1, 2, 8]), list([1, 3, 2]),
#        list([1, 3, 3]), list([1, 3, 5]), list([1, 3, 7]), list([1, 3, 8]),
#        list([1, 4, 1]), list([1, 4, 6]), list([1, 4, 9]), list([1, 5, 1]),
#        list([1, 5, 2]), list([1, 5, 3]), list([1, 5, 4]), list([1, 5, 6]),
#        list([1, 5, 9]), list([1, 6, 1]), list([1, 6, 2]), list([1, 6, 5]),
#        list([1, 6, 7]), list([1, 7, 4]), list([1, 7, 7]), list([1, 7, 9]),
#        list([1, 8, 1]), list([1, 8, 3]), list([1, 8, 4]), list([1, 8, 7]),
#        list([1, 8, 8]), list([1, 8, 9]), list([1, 9, 1]), list([1, 9, 2]),
#        list([1, 9, 4]), list([1, 9, 6]), list([2, 1, 1]), list([2, 1, 4]),
#        list([2, 1, 5]), list([2, 1, 6]), list([2, 2, 1]), list([2, 2, 2]),
#        list([2, 2, 4]), list([2, 2, 5]), list([2, 2, 7]), list([2, 2, 8]),
#        list([2, 2, 9]), list([2, 3, 1]), list([2, 3, 2]), list([2, 3, 7]),
#        list([2, 3, 8]), list([2, 4, 2]), list([2, 4, 5]), list([2, 4, 6]),
#        list([2, 4, 7]), list([2, 4, 8]), list([2, 5, 1]), list([2, 5, 5]),
#        list([2, 5, 7]), list([2, 5, 9]), list([2, 6, 3]), list([2, 6, 5]),
#        list([2, 6, 8]), list([2, 7, 1]), list([2, 7, 2]), list([2, 7, 3]),
#        list([2, 7, 7]), list([2, 8, 3]), list([2, 8, 5]), list([2, 8, 9]),
#        list([2, 9, 3]), list([2, 9, 6]), list([2, 9, 7]), list([2, 9, 9]),
#        list([3, 1, 1]), list([3, 2, 2]), list([3, 2, 3]), list([3, 2, 6]),
#        list([3, 2, 9]), list([3, 3, 4]), list([3, 3, 5]), list([3, 3, 6]),
#        list([3, 4, 1]), list([3, 4, 3]), list([3, 4, 4]), list([3, 5, 2]),
#        list([3, 5, 7]), list([3, 5, 9]), list([3, 6, 2]), list([3, 6, 6]),
#        list([3, 6, 7]), list([3, 7, 3]), list([3, 7, 5]), list([3, 7, 6]),
#        list([3, 7, 7]), list([3, 7, 9]), list([3, 8, 2]), list([3, 8, 7]),
#        list([3, 8, 9]), list([3, 9, 3]), list([4, 1, 1]), list([4, 1, 2]),
#        list([4, 1, 8]), list([4, 1, 9]), list([4, 2, 5]), list([4, 2, 8]),
#        list([4, 3, 3]), list([4, 3, 4]), list([4, 4, 1]), list([4, 4, 2]),
#        list([4, 4, 3]), list([4, 4, 6]), list([4, 4, 7]), list([4, 5, 1]),
#        list([4, 5, 5]), list([4, 5, 6]), list([4, 5, 7]), list([4, 5, 8]),
#        list([4, 6, 2]), list([4, 6, 4]), list([4, 6, 5]), list([4, 6, 6]),
#        list([4, 6, 8]), list([4, 7, 2]), list([4, 7, 4]), list([4, 7, 7]),
#        list([4, 7, 9]), list([4, 8, 1]), list([4, 8, 3]), list([4, 8, 5]),
#        list([4, 8, 8]), list([4, 8, 9]), list([4, 9, 1]), list([4, 9, 3]),
#        list([4, 9, 5]), list([4, 9, 7]), list([5, 1, 1]), list([5, 1, 3]),
#        list([5, 1, 6]), list([5, 1, 8]), list([5, 1, 9]), list([5, 2, 1]),
#        list([5, 2, 3]), list([5, 2, 7]), list([5, 3, 2]), list([5, 3, 6]),
#        list([5, 3, 7]), list([5, 3, 9]), list([5, 4, 1]), list([5, 4, 2]),
#        list([5, 4, 3]), list([5, 4, 4]), list([5, 4, 6]), list([5, 4, 8]),
#        list([5, 5, 1]), list([5, 5, 6]), list([5, 5, 8]), list([5, 6, 1]),
#        list([5, 6, 2]), list([5, 6, 4]), list([5, 6, 6]), list([5, 6, 8]),
#        list([5, 7, 3]), list([5, 7, 4]), list([5, 7, 7]), list([5, 7, 8]),
#        list([5, 7, 9]), list([5, 8, 1]), list([5, 8, 9]), list([5, 9, 1]),
#        list([5, 9, 5]), list([5, 9, 6]), list([5, 9, 7]), list([5, 9, 9]),
#        list([6, 1, 2]), list([6, 1, 3]), list([6, 1, 4]), list([6, 1, 9]),
#        list([6, 2, 1]), list([6, 2, 5]), list([6, 3, 1]), list([6, 3, 5]),
#        list([6, 3, 6]), list([6, 3, 7]), list([6, 3, 8]), list([6, 4, 2]),
#        list([6, 4, 9]), list([6, 5, 1]), list([6, 5, 2]), list([6, 5, 3]),
#        list([6, 5, 5]), list([6, 5, 7]), list([6, 5, 8]), list([6, 5, 9]),
#        list([6, 6, 1]), list([6, 6, 2]), list([6, 6, 8]), list([6, 6, 9]),
#        list([6, 7, 2]), list([6, 7, 7]), list([6, 7, 8]), list([6, 8, 1]),
#        list([6, 8, 2]), list([6, 8, 3]), list([6, 8, 4]), list([6, 8, 7]),
#        list([6, 8, 8]), list([6, 8, 9]), list([6, 9, 2]), list([6, 9, 3]),
#        list([6, 9, 4]), list([6, 9, 5]), list([6, 9, 6]), list([6, 9, 8]),
#        list([6, 9, 9]), list([7, 1, 1]), list([7, 1, 2]), list([7, 1, 4]),
#        list([7, 1, 5]), list([7, 2, 3]), list([7, 2, 6]), list([7, 4, 2]),
#        list([7, 4, 3]), list([7, 4, 5]), list([7, 5, 2]), list([7, 5, 6]),
#        list([7, 5, 7]), list([7, 5, 9]), list([7, 6, 5]), list([7, 6, 6]),
#        list([7, 6, 7]), list([7, 7, 1]), list([7, 7, 2]), list([7, 7, 3]),
#        list([7, 7, 4]), list([7, 7, 5]), list([7, 7, 6]), list([7, 7, 7]),
#        list([7, 7, 9]), list([7, 8, 2]), list([7, 8, 4]), list([7, 8, 5]),
#        list([7, 8, 6]), list([7, 8, 7]), list([7, 8, 8]), list([7, 8, 9]),
#        list([7, 9, 1]), list([7, 9, 7]), list([7, 9, 8]), list([7, 9, 9]),
#        list([8, 1, 1]), list([8, 1, 2]), list([8, 1, 5]), list([8, 1, 8]),
#        list([8, 1, 9]), list([8, 2, 4]), list([8, 2, 6]), list([8, 3, 2]),
#        list([8, 3, 7]), list([8, 3, 8]), list([8, 4, 4]), list([8, 4, 5]),
#        list([8, 4, 8]), list([8, 5, 1]), list([8, 5, 3]), list([8, 5, 4]),
#        list([8, 5, 6]), list([8, 6, 3]), list([8, 6, 5]), list([8, 7, 1]),
#        list([8, 7, 3]), list([8, 7, 4]), list([8, 7, 7]), list([8, 8, 2]),
#        list([8, 9, 2]), list([8, 9, 3]), list([8, 9, 5]), list([8, 9, 8]),
#        list([8, 9, 9]), list([9, 1, 1]), list([9, 1, 8]), list([9, 2, 2]),
#        list([9, 2, 4]), list([9, 2, 5]), list([9, 2, 6]), list([9, 2, 8]),
#        list([9, 3, 2]), list([9, 3, 3]), list([9, 3, 5]), list([9, 4, 6]),
#        list([9, 4, 7]), list([9, 4, 9]), list([9, 5, 2]), list([9, 5, 3]),
#        list([9, 5, 6]), list([9, 5, 8]), list([9, 5, 9]), list([9, 6, 3]),
#        list([9, 6, 5]), list([9, 6, 7]), list([9, 7, 6]), list([9, 7, 7]),
#        list([9, 7, 8]), list([9, 7, 9]), list([9, 8, 7]), list([9, 9, 2]),
#        list([9, 9, 4]), list([9, 9, 5]), list([9, 9, 6])], dtype=object)
