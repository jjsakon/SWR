# %%
import warnings
warnings.simplefilter('ignore')
import pandas as pd
import numpy as np
import cmlreaders as cml
from ptsa.data.readers import EEGReader
from ptsa.data.MatlabIO import read_single_matlab_matrix_as_numpy_structured_array

# %% [markdown]
# ### Grab raw events and montage

# %% [markdown]
# One very helpful function for reading matlab events!!

# %%
events = pd.DataFrame.from_records(
    read_single_matlab_matrix_as_numpy_structured_array(
        '/data/eeg/UT159/behavioral/FR1_scopolamine/session_1/events.mat', 'events'
    )
)
events # note that the eegfile is wrong
# Out:
#     subject  session  list  serialpos             type  item  itemno  \
# 0     UT159        1  -999       -999                B     X    -999
# 1     UT159        1  -999       -999       SESS_START     X    -999
# 2     UT159        1  -999       -999  COUNTDOWN_START     X    -999
# 3     UT159        1  -999       -999    COUNTDOWN_END     X    -999
# 4     UT159        1  -999       -999    PRACTICE_WORD     X    -999
# ..      ...      ...   ...        ...              ...   ...     ...
# 691   UT159        1    25       -999         REC_WORD  MOLE     155
# 692   UT159        1    25       -999         REC_WORD  HOLE     124
# 693   UT159        1    25       -999          REC_END     X    -999
# 694   UT159        1    25       -999         SESS_END     X    -999
# 695   UT159        1    25       -999                E     X    -999
#
#      recalled        mstime  msoffset  ...  intrusion  isStim  expVersion  \
# 0        -999  1.564763e+12         0  ...       -999    -999
# 1        -999  1.564763e+12         0  ...       -999    -999      v_1.05
# 2        -999  1.564763e+12         0  ...       -999    -999      v_1.05
# 3        -999  1.564763e+12         0  ...       -999    -999      v_1.05
# 4        -999  1.564763e+12         1  ...       -999    -999      v_1.05
# ..        ...           ...       ...  ...        ...     ...         ...
# 691      -999  1.564766e+12      -999  ...          0    -999      v_1.05
# 692      -999  1.564766e+12      -999  ...          0    -999      v_1.05
# 693      -999  1.564766e+12         1  ...       -999    -999      v_1.05
# 694      -999  1.564766e+12         0  ...       -999    -999      v_1.05
# 695      -999  1.564766e+12         0  ...       -999    -999      v_1.05
#
#     stimLoc stimAmp  stimAnode  stimCathode  stimList  \
# 0         X     NaN        NaN          NaN      -999
# 1         X     NaN        NaN          NaN      -999
# 2         X     NaN        NaN          NaN      -999
# 3         X     NaN        NaN          NaN      -999
# 4         X     NaN        NaN          NaN      -999
# ..      ...     ...        ...          ...       ...
# 691       X     NaN        NaN          NaN      -999
# 692       X     NaN        NaN          NaN      -999
# 693       X     NaN        NaN          NaN      -999
# 694       X     NaN        NaN          NaN      -999
# 695       X     NaN        NaN          NaN      -999
#
#                                                eegfile eegoffset
# 0    /project/TIBIR/Lega_lab/shared/lega_ansir/subj...    109250
# 1    /project/TIBIR/Lega_lab/shared/lega_ansir/subj...    109364
# 2    /project/TIBIR/Lega_lab/shared/lega_ansir/subj...    131034
# 3    /project/TIBIR/Lega_lab/shared/lega_ansir/subj...    141461
# 4    /project/TIBIR/Lega_lab/shared/lega_ansir/subj...    145136
# ..                                                 ...       ...
# 691  /project/TIBIR/Lega_lab/shared/lega_ansir/subj...   2661095
# 692  /project/TIBIR/Lega_lab/shared/lega_ansir/subj...   2664950
# 693  /project/TIBIR/Lega_lab/shared/lega_ansir/subj...   2686604
# 694  /project/TIBIR/Lega_lab/shared/lega_ansir/subj...   2696252
# 695  /project/TIBIR/Lega_lab/shared/lega_ansir/subj...   2696281
#
# [696 rows x 21 columns]

# %%
contacts = pd.DataFrame.from_records(np.recfromtxt("/data/eeg/UT159/eeg.noreref/jacksheet.txt", encoding='utf-8'))
contacts = contacts.rename(columns={'f0':'contact', 'f1':'label'})
contacts[:10]
# Out:
#    contact label
# 0        1   RB1
# 1        2   RB2
# 2        3   RB3
# 3        4   RB4
# 4        5   RB5
# 5        6   RB6
# 6        7   RB7
# 7        8   RB8
# 8        9   RB9
# 9       10  RB10

# %% [markdown]
# ### Localization info
# Only one thing left: grab the localization info. Looks like it's not so consistently formatted (would be better as a .csv) so maybe necessary to parse line by line

# %%
with open("/data/eeg/UT159/docs/UT159_depth_el_info.txt", 'r') as f:
    lines = f.readlines()
lines = [line.rstrip('\n') for line in lines]

# %%
depth_info = pd.DataFrame(columns=['label', 'description'])
for line in lines:
    split = line.split()
    try:
        depth_info = depth_info.append({'label':split[1], 'description':' '.join(split[2:])}, ignore_index=True)
    except IndexError:
        continue
contacts = depth_info.merge(contacts, how='inner')    
contacts[:10]
# Out:
#   label              description  contact
# 0   RB1     Anterior hippocampus        1
# 1   RB2  Anterior hippocampus/WM        2
# 2   RB3                       WM        3
# 3   RB4                       WM        4
# 4   RB5                       WM        5
# 5   RB6                       WM        6
# 6   RB7                  STS/STG        7
# 7   RB8                  STS/STG        8
# 8   RB9                  STS/STG        9
# 9  RB10                      OUT       10

# %% [markdown]
# Now we have an updated contacts df with anatomic locations from the UTSW localizations!
#
# ## Read EEG
# Next, use the base file name in eeg.noreref to read the binary channel data

# %%
# We want to get the base file name in a clean/systematic way, probably by globbing on the experiment_session name 
from glob import glob
import os
root = '/data/eeg'
subject = 'UT159'
experiment = 'FR1_scopolamine'
session = 1
paths = glob(os.path.join(root, subject, 'eeg.noreref', subject+'_'+experiment+'_'+str(session)+'*'), recursive=True)
file_base = os.path.basename(paths[0]).split('.')[0]
base_name = os.path.join(os.path.dirname(paths[0]), file_base)
base_name
# Out:
# '/data/eeg/UT159/eeg.noreref/UT159_FR1_scopolamine_1_02Aug19_1109'

# %%
events['eegfile'] = base_name
events = events[events.type=='WORD']
events[0:10]
# Out:
#    subject  session  list  serialpos  type   item  itemno  recalled  \
# 24   UT159        1     1          1  WORD  STOVE     256         0
# 25   UT159        1     1          2  WORD   CALF      41         1
# 26   UT159        1     1          3  WORD    MUG     162         0
# 27   UT159        1     1          4  WORD    APE       2         1
# 28   UT159        1     1          5  WORD    FOX     104         1
# 29   UT159        1     1          6  WORD   WOLF     295         1
# 30   UT159        1     1          7  WORD   HOOK     126         1
# 31   UT159        1     1          8  WORD   BARN      11         0
# 32   UT159        1     1          9  WORD   NOSE     167         0
# 33   UT159        1     1         10  WORD    HEN     122         1
#
#           mstime  msoffset  ...  intrusion  isStim  expVersion stimLoc  \
# 24  1.564763e+12         1  ...       -999       0      v_1.05       X
# 25  1.564763e+12         1  ...       -999       0      v_1.05       X
# 26  1.564763e+12         1  ...       -999       0      v_1.05       X
# 27  1.564763e+12         1  ...       -999       0      v_1.05       X
# 28  1.564763e+12         1  ...       -999       0      v_1.05       X
# 29  1.564763e+12         1  ...       -999       0      v_1.05       X
# 30  1.564763e+12         1  ...       -999       0      v_1.05       X
# 31  1.564763e+12         1  ...       -999       0      v_1.05       X
# 32  1.564763e+12         1  ...       -999       0      v_1.05       X
# 33  1.564763e+12         1  ...       -999       0      v_1.05       X
#
#    stimAmp  stimAnode  stimCathode  stimList  \
# 24     NaN        NaN          NaN         0
# 25     NaN        NaN          NaN         0
# 26     NaN        NaN          NaN         0
# 27     NaN        NaN          NaN         0
# 28     NaN        NaN          NaN         0
# 29     NaN        NaN          NaN         0
# 30     NaN        NaN          NaN         0
# 31     NaN        NaN          NaN         0
# 32     NaN        NaN          NaN         0
# 33     NaN        NaN          NaN         0
#
#                                               eegfile eegoffset
# 24  /data/eeg/UT159/eeg.noreref/UT159_FR1_scopolam...    261401
# 25  /data/eeg/UT159/eeg.noreref/UT159_FR1_scopolam...    263802
# 26  /data/eeg/UT159/eeg.noreref/UT159_FR1_scopolam...    266185
# 27  /data/eeg/UT159/eeg.noreref/UT159_FR1_scopolam...    268802
# 28  /data/eeg/UT159/eeg.noreref/UT159_FR1_scopolam...    271219
# 29  /data/eeg/UT159/eeg.noreref/UT159_FR1_scopolam...    273836
# 30  /data/eeg/UT159/eeg.noreref/UT159_FR1_scopolam...    276436
# 31  /data/eeg/UT159/eeg.noreref/UT159_FR1_scopolam...    278970
# 32  /data/eeg/UT159/eeg.noreref/UT159_FR1_scopolam...    281421
# 33  /data/eeg/UT159/eeg.noreref/UT159_FR1_scopolam...    283838
#
# [10 rows x 21 columns]

# %%
eeg = EEGReader(events.to_records(),
                channels= contacts.contact.values[contacts.description.str.contains('hippocampus')],
                start_time=0, end_time=0.3).read()

# %%
eeg
# Out:
# <xarray.TimeSeries (channels: 8, events: 300, time: 300)>
# array([[[-1.36718750e+00,  1.01562500e+01,  2.08984375e+01, ...,
#           9.08203125e+01,  7.48046875e+01,  6.05468750e+01],
#         [-1.19140625e+02, -1.35546875e+02, -1.45410156e+02, ...,
#          -2.26367188e+02, -2.12011719e+02, -2.03906250e+02],
#         [-1.23925781e+02, -1.24609375e+02, -1.22656250e+02, ...,
#           7.58789062e+01,  7.99804688e+01,  8.31054688e+01],
#         ...,
#         [-2.55859375e+01, -1.37695312e+01, -2.73437500e+00, ...,
#           3.99414062e+01,  4.73632812e+01,  5.39062500e+01],
#         [ 2.58203125e+02,  2.62109375e+02,  2.64941406e+02, ...,
#           3.66992188e+02,  3.74707031e+02,  3.77929688e+02],
#         [ 9.00390625e+01,  1.04589844e+02,  1.17578125e+02, ...,
#           2.00000000e+02,  2.13671875e+02,  2.20117188e+02]],
#
#        [[-1.84667969e+02, -1.82226562e+02, -1.79785156e+02, ...,
#          -2.33886719e+02, -2.33105469e+02, -2.30273438e+02],
#         [-9.84375000e+01, -1.00097656e+02, -1.01171875e+02, ...,
#           9.47265625e+00,  7.51953125e+00,  3.61328125e+00],
#         [ 2.24414062e+02,  2.25976562e+02,  2.31054688e+02, ...,
#           2.14160156e+02,  2.17089844e+02,  2.14843750e+02],
#         ...,
#         [ 2.75195312e+02,  2.77246094e+02,  2.82910156e+02, ...,
#           1.55761719e+02,  1.60546875e+02,  1.62695312e+02],
#         [ 7.74414062e+01,  7.49023438e+01,  7.18750000e+01, ...,
#           7.07031250e+01,  6.83593750e+01,  6.28906250e+01],
#         [-8.26171875e+01, -8.05664062e+01, -7.96875000e+01, ...,
#          -1.05468750e+02, -1.03417969e+02, -1.06542969e+02]],
#
#        [[ 9.08203125e+01,  1.06445312e+02,  1.17773438e+02, ...,
#           4.15039062e+01,  4.56054688e+01,  5.39062500e+01],
#         [ 6.74804688e+01,  5.98632812e+01,  5.23437500e+01, ...,
#          -7.59765625e+01, -7.78320312e+01, -8.03710938e+01],
#         [ 3.18359375e+01,  3.08593750e+01,  3.17382812e+01, ...,
#   * events      (events) (numpy.record, [('index', '<i8'), ('subject', 'O'), ('session', '<i8'), ('list', '<i8'), ('serialpos', '<i8'), ('type', 'O'), ('item', 'O'), ('itemno', '<i8'), ('recalled', '<i8'), ('mstime', '<f8'), ('msoffset', '<i8'), ('rectime', '<i8'), ('intrusion', '<i8'), ('isStim', '<i8'), ('expVersion', 'O'), ('stimLoc', 'O'), ('stimAmp', '<f8'), ('stimAnode', '<f8'), ('stimCathode', '<f8'), ('stimList', '<i8'), ('eegfile', 'O'), ('eegoffset', '<i8')]) (24, 'UT159', 1, 1, 1, 'WORD', 'STOVE', 256, 0, 1.56476325e+12, 1, -999, -999, 0, 'v_1.05', 'X', nan, nan, nan, 0, '/data/eeg/UT159/eeg.noreref/UT159_FR1_scopolamine_1_02Aug19_1109', 261401) ... (683, 'UT159', 1, 25, 12, 'WORD', 'SNAKE', 235, 1, 1.56476562e+12, 1, 1500, -999, 0, 'v_1.05', 'X', nan, nan, nan, 0, '/data/eeg/UT159/eeg.noreref/UT159_FR1_scopolamine_1_02Aug19_1109', 2632210)
#   * time        (time) float64 0.0 0.001 0.002 0.003 ... 0.296 0.297 0.298 0.299
#     samplerate  float64 1e+03
# Attributes:
#     samplerate:  1000.0
#     format:      int16
#     gain:        0.09765625

# %%
from ptsa.data.filters import MorletWaveletFilter

# %%
MorletWaveletFilter(eeg, [3., 8.], output='power').filter()
# Out:
# CPP total time wavelet loop:  0.19980406761169434
# <xarray.TimeSeries (frequency: 2, channels: 8, events: 300, time: 300)>
# array([[[[2.53483184e+08, 2.55638329e+08, 2.57808635e+08, ...,
#           1.01598157e+09, 1.01602055e+09, 1.01602668e+09],
#          [5.77712426e+08, 5.80784214e+08, 5.83858168e+08, ...,
#           9.58642168e+08, 9.56779402e+08, 9.54896535e+08],
#          [9.77634447e+08, 9.82037241e+08, 9.86435611e+08, ...,
#           1.22149397e+09, 1.21770368e+09, 1.21389316e+09],
#          ...,
#          [1.24222412e+08, 1.24921435e+08, 1.25621151e+08, ...,
#           2.07801672e+08, 2.07340843e+08, 2.06875495e+08],
#          [1.12598845e+08, 1.12577344e+08, 1.12560551e+08, ...,
#           4.55024130e+08, 4.56216803e+08, 4.57394660e+08],
#          [1.65602529e+08, 1.66649031e+08, 1.67698101e+08, ...,
#           3.46200820e+08, 3.45680103e+08, 3.45150754e+08]],
#
#         [[3.99522104e+08, 3.99862547e+08, 4.00200401e+08, ...,
#           5.51297318e+08, 5.51419055e+08, 5.51528879e+08],
#          [1.65134404e+07, 1.64568046e+07, 1.63998094e+07, ...,
#           8.90576366e+06, 8.92270559e+06, 8.93953936e+06],
#          [2.01204396e+08, 2.00614152e+08, 2.00024289e+08, ...,
#           3.85571001e+08, 3.86694656e+08, 3.87806861e+08],
#          ...,
#          [6.88956840e+08, 6.88659611e+08, 6.88345674e+08, ...,
#           4.03519162e+08, 4.02900638e+08, 4.02282181e+08],
#          [3.45962570e+08, 3.47168618e+08, 3.48370662e+08, ...,
#           3.43106215e+08, 3.41870956e+08, 3.40631808e+08],
#          [7.33342694e+07, 7.35804948e+07, 7.38274851e+07, ...,
#           1.47529740e+08, 1.47503657e+08, 1.47473749e+08]],
#
#         [[2.49612239e+08, 2.51111377e+08, 2.52615713e+08, ...,
#           4.81409903e+07, 4.78541485e+07, 4.75635476e+07],
#          [9.81106197e+06, 9.83298032e+06, 9.85304743e+06, ...,
#           1.12688259e+07, 1.13399425e+07, 1.14085624e+07]],
#
#         [[4.28014284e+07, 4.29538723e+07, 4.31015554e+07, ...,
#           2.69281799e+07, 2.67764519e+07, 2.66241720e+07],
#          [3.81063483e+08, 3.81160965e+08, 3.81178345e+08, ...,
#           1.08034421e+08, 1.08565975e+08, 1.09070886e+08],
#          [1.18363744e+07, 1.19882654e+07, 1.21427890e+07, ...,
#           8.77789830e+07, 8.66544609e+07, 8.55311154e+07],
#          ...,
#          [1.53253972e+08, 1.53053799e+08, 1.52817804e+08, ...,
#           1.88467132e+07, 1.86976156e+07, 1.85455955e+07],
#          [7.59110409e+07, 7.60257954e+07, 7.61267362e+07, ...,
#           7.27248962e+07, 7.24818310e+07, 7.22267719e+07],
#          [3.51295765e+07, 3.53633951e+07, 3.55934269e+07, ...,
#           3.28809759e+07, 3.27217839e+07, 3.25589682e+07]],
#
#         [[8.93456071e+07, 8.95613031e+07, 8.97626472e+07, ...,
#           4.30133460e+07, 4.28999316e+07, 4.27823974e+07],
#          [2.03150000e+08, 2.04325044e+08, 2.05474616e+08, ...,
#           2.44770882e+07, 2.43067866e+07, 2.41418603e+07],
#          [7.90323960e+06, 7.70577241e+06, 7.51221601e+06, ...,
#           1.64887426e+07, 1.58306890e+07, 1.51945011e+07],
#          ...,
#          [5.96073465e+07, 5.99195980e+07, 6.02269156e+07, ...,
#           6.32298585e+06, 6.29186792e+06, 6.26047272e+06],
#          [7.31468652e+06, 7.42267381e+06, 7.53161539e+06, ...,
#           1.53528675e+06, 1.48186949e+06, 1.42980798e+06],
#          [1.40416698e+08, 1.40957558e+08, 1.41476350e+08, ...,
#           1.65078189e+08, 1.65103605e+08, 1.65098081e+08]]]])
# Coordinates:
#   * channels    (channels) int64 1 2 43 44 45 223 224 225
#   * events      (events) (numpy.record, [('index', '<i8'), ('subject', 'O'), ('session', '<i8'), ('list', '<i8'), ('serialpos', '<i8'), ('type', 'O'), ('item', 'O'), ('itemno', '<i8'), ('recalled', '<i8'), ('mstime', '<f8'), ('msoffset', '<i8'), ('rectime', '<i8'), ('intrusion', '<i8'), ('isStim', '<i8'), ('expVersion', 'O'), ('stimLoc', 'O'), ('stimAmp', '<f8'), ('stimAnode', '<f8'), ('stimCathode', '<f8'), ('stimList', '<i8'), ('eegfile', 'O'), ('eegoffset', '<i8')]) (24, 'UT159', 1, 1, 1, 'WORD', 'STOVE', 256, 0, 1.56476325e+12, 1, -999, -999, 0, 'v_1.05', 'X', nan, nan, nan, 0, '/data/eeg/UT159/eeg.noreref/UT159_FR1_scopolamine_1_02Aug19_1109', 261401) ... (683, 'UT159', 1, 25, 12, 'WORD', 'SNAKE', 235, 1, 1.56476562e+12, 1, 1500, -999, 0, 'v_1.05', 'X', nan, nan, nan, 0, '/data/eeg/UT159/eeg.noreref/UT159_FR1_scopolamine_1_02Aug19_1109', 2632210)
#   * time        (time) float64 0.0 0.001 0.002 0.003 ... 0.296 0.297 0.298 0.299
#     samplerate  float64 1e+03
#   * frequency   (frequency) float64 3.0 8.0
